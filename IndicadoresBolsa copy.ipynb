# %%
import pandas as pd

# %% [markdown]
# ## Initiate dataframe

# %%
df_status=pd.read_csv("statusinvest-busca-avancada.csv", sep=';')

# %%
df_status
# Out:
#      TICKER   PRECO    DY      P/L    P/VP P/ATIVOS MARGEM BRUTA MARGEM EBIT  \
# 0         A  107,76  0,84    27,83    5,67     2,95        50,93       21,02
# 1        AA   24,71  1,62    -4,92    0,98     0,32         5,98       -6,05
# 2      AACG    0,87   NaN    -2,65    1,20     0,38        51,68      -31,49
# 3      AACQ    9,99   NaN   -93,43  180,94     1,25          NaN         NaN
# 4     AACQU   11,05   NaN  -103,35  200,14     1,38          NaN         NaN
# ...     ...     ...   ...      ...     ...      ...          ...         ...
# 6169    ZUO    7,90   NaN    -5,94    9,85     1,63        63,04      -38,05
# 6170    ZVO    0,09   NaN    -0,08    0,47     0,04        35,09      -17,75
# 6171   ZYME    7,30   NaN     3,02    1,14     0,85       100,00       40,70
# 6172   ZYNE    1,30   NaN    -1,87    2,42     1,73          NaN         NaN
# 6173   ZYXI    8,94   NaN    18,98    5,17     2,00        79,83       11,40
#
# ...

# %%
risk=0.131

Bazin=DPA/0.06

if VPA>0 and LPA>0:
    Graham=(22,5*LPA*VPA)^0.5

crescimento_esperado=(1-Payout)*ROE

if CAGR LUCRO 5A==0:
    media_crescimento=crescimento_esperado
elif crescimento_esperado==0:
    media_crescimento=CAGR LUCRO 5
else:
    media_crescimento=(crescimento_esperado+CAGR LUCRO5A)/2

if D1>0:
    D1=DPA*(1+CAGR LUCRO 5A)

Gordon = D1/(risk-CAGR LUCRO5A)
